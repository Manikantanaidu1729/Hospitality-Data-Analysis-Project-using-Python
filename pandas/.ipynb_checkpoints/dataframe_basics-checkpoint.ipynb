# %%
import pandas as pd

# %%
df=pd.read_csv("movies.csv")
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.shape
# Out:
# (37, 10)

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='object')

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# Hollywood    20
# Bollywood    17
# Name: industry, dtype: int64

# %%
df.language.value_counts()
# Out:
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: language, dtype: int64

# %%
new_df= df[["title","industry","imdb_rating"]]

# %%
new_df.head(2)
# Out:
#                                          title   industry  imdb_rating
# 0                              Pather Panchali  Bollywood          8.3
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          7.0

# %%
df[(df.release_year==2000) | (df.release_year==2001)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 8                  Gladiator  Hollywood          2000          8.5
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
#
#                   studio  budget  revenue      unit currency language
# 8   Universal Pictures     103.0    460.5  Millions      USD  English
# 23    Dharma Productions   390.0   1360.0  Millions      INR    Hindi

# %%
df[0]  # this type of notation is suitable for columns only for "df" and if 0 is implicit index then it is also suitable for df.iloc else suitable for df.loc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %%
df[0]["release_year"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %%
df[0:1]["release_year"]
# Out:
# 0    1955
# Name: release_year, dtype: int64

# %%
df.iloc[0:1]["release_year"]
# Out:
# 0    1955
# Name: release_year, dtype: int64

# %%
df.iloc[0]["release_year"]
# Out:
# 1955

# %%
type(df.iloc[0]["release_year"])
# Out:
# numpy.int64

# %%
df.iloc[0:2][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-961478eb03d3> in <module>
# ----> 1 df.iloc[0:2][0]
#
# ...

# %%
df.iloc[0]
# Out:
# industry                            Bollywood
# release_year                             1955
# imdb_rating                               8.3
# studio              Government of West Bengal
# budget                                70000.0
# revenue                              100000.0
# unit                                Thousands
# currency                                  INR
# language                              Bengali
# age_of_the_movie                           68
# profit                                30000.0
# Name: Pather Panchali, dtype: object

# %%
df[df.studio=="Marvel Studios"]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df.groupby("title")["imdb_rating"].describe()
# Out:
#                                              count  mean  std  min  25%  50%  \
# title
# 3 Idiots                                       1.0   8.4  NaN  8.4  8.4  8.4
# Avatar                                         1.0   7.8  NaN  7.8  7.8  7.8
# Avengers: Endgame                              1.0   8.4  NaN  8.4  8.4  8.4
# Avengers: Infinity War                         1.0   8.4  NaN  8.4  8.4  8.4
# Baahubali: The Beginning                       1.0   8.0  NaN  8.0  8.0  8.0
# Bajirao Mastani                                1.0   7.2  NaN  7.2  7.2  7.2
# Bajrangi Bhaijaan                              1.0   8.1  NaN  8.1  8.1  8.1
# Captain America: The First Avenger             1.0   6.9  NaN  6.9  6.9  6.9
# Captain America: The Winter Soldier            1.0   7.8  NaN  7.8  7.8  7.8
# Dilwale Dulhania Le Jayenge                    1.0   8.0  NaN  8.0  8.0  8.0
# Doctor Strange in the Multiverse of Madness    1.0   7.0  NaN  7.0  7.0  7.0
# ...

# %%
df[(df.imdb_rating==min(df.imdb_rating)) | (df.imdb_rating==max(df.imdb_rating))][["title","imdb_rating"]]
# Out:
#                        title  imdb_rating
# 5   The Shawshank Redemption          9.3
# 31                    Race 3          1.9

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
import datetime

# %%
df["age_of_the_movie"] = datetime.datetime.now().year - df.release_year  # df["age_of_the_movie"] = df["release_year"].apply(lambda x: 2023 - x)   same behaviour we can observe when run this

# %%
df.head(3)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
#
#   currency language  age_of_the_movie
# 0      INR  Bengali                68
# 1      USD  English                 1
# 2      USD  English                10

# %%
df["profit"] = df["revenue"]-df["budget"]   # df["profit"] = df.apply(lambda x : x["revenue"]-x["budget"],axis=1)

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age_of_the_movie   profit
# 0      INR  Bengali                68  30000.0
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37, step=1)

# %%
df.set_index("title",inplace=True)

# %%
df.head()
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
# Thor: Ragnarok                               Hollywood          2017
# Thor: Love and Thunder                       Hollywood          2022
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
# Thor: Ragnarok                                       7.9
# Thor: Love and Thunder                               6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# ...

# %%
df.index
# Out:
# Index(['Pather Panchali', 'Doctor Strange in the Multiverse of Madness',
#        'Thor: The Dark World ', 'Thor: Ragnarok ', 'Thor: Love and Thunder ',
#        'The Shawshank Redemption', 'Interstellar', 'The Pursuit of Happyness',
#        'Gladiator', 'Titanic', 'It's a Wonderful Life', 'Avatar',
#        'The Godfather', 'The Dark Knight', 'Schindler's List', 'Jurassic Park',
#        'Parasite', 'Avengers: Endgame', 'Avengers: Infinity War',
#        'Captain America: The First Avenger',
#        'Captain America: The Winter Soldier', 'Dilwale Dulhania Le Jayenge',
#        '3 Idiots', 'Kabhi Khushi Kabhie Gham', 'Bajirao Mastani ',
#        'Taare Zameen Par', 'Munna Bhai M.B.B.S.', 'PK', 'Sanju',
#        'The Kashmir Files', 'Bajrangi Bhaijaan', 'Race 3', 'Shershaah',
#        'K.G.F: Chapter 2', 'Pushpa: The Rise - Part 1', 'RRR',
#        'Baahubali: The Beginning'],
#       dtype='object', name='title')

# %%
df.loc["Pather Panchali"]
# Out:
# industry                            Bollywood
# release_year                             1955
# imdb_rating                               8.3
# studio              Government of West Bengal
# budget                                70000.0
# revenue                              100000.0
# unit                                Thousands
# currency                                  INR
# language                              Bengali
# age_of_the_movie                           68
# profit                                30000.0
# Name: Pather Panchali, dtype: object

# %%
df.loc[['Pather Panchali', 'Doctor Strange in the Multiverse of Madness','Thor: The Dark World ']]
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
# Thor: The Dark World                                    Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# ...

# %%
df.iloc[0:3]
# Out:
#                                               industry  release_year  \
# title
# Pather Panchali                              Bollywood          1955
# Doctor Strange in the Multiverse of Madness  Hollywood          2022
# Thor: The Dark World                         Hollywood          2013
#
#                                              imdb_rating  \
# title
# Pather Panchali                                      8.3
# Doctor Strange in the Multiverse of Madness          7.0
# Thor: The Dark World                                 6.8
#
#                                                                 studio  \
# title
# Pather Panchali                              Government of West Bengal
# Doctor Strange in the Multiverse of Madness             Marvel Studios
# Thor: The Dark World                                    Marvel Studios
#
#                                               budget   revenue       unit  \
# title
# ...

# %%
df.iloc[0]
# Out:
# industry                            Bollywood
# release_year                             1955
# imdb_rating                               8.3
# studio              Government of West Bengal
# budget                                70000.0
# revenue                              100000.0
# unit                                Thousands
# currency                                  INR
# language                              Bengali
# age_of_the_movie                           68
# profit                                30000.0
# Name: Pather Panchali, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age_of_the_movie   profit
# 0      INR  Bengali                68  30000.0
# ...

# %% [markdown]
# #### exercise

# %%
# **Peter Pandey** arrived in Bangalore(a city in India) with the aim of finding a suitable house that fits his budget and location preferences.
#   He has some queries related to house selection and is seeking solutions.
# Help Peter Pandey to answer his questions and you are provided with a sample dataset of house information that contain area_type, availability, location, size, society, total_sqft, bath, balcony, and price.

# %%
data = pd.read_csv("bengaluru_house_prices.csv")

# %%
data.head()
# Out:
#               area_type   availability        location       size  society  \
# 0  Super built-up  Area  Ready To Move  Ambedkar Nagar      3 BHK      NaN
# 1            Plot  Area         18-Aug        Hulimavu  4 Bedroom  ValleCi
# 2  Super built-up  Area  Ready To Move         Kalkere      2 BHK  Sothin
# 3            Plot  Area  Ready To Move     Kodigehalli  2 Bedroom      NaN
# 4  Super built-up  Area  Ready To Move          Harlur      2 BHK  Prncyrn
#
#    total_sqft  bath  balcony  price
# 0        1920   4.0      2.0  121.0
# 1        1500   4.0      3.0  192.0
# 2         925   2.0      1.0   55.0
# 3         500   1.0      0.0   55.0
# 4        1174   2.0      1.0   74.0

# %%
data.shape
# Out:
# (37, 12)

# %%
data[["area_type","size"]].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-62f163051978> in <module>
# ----> 1 data[["area_type","size"]].unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
data["area_type"].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
data["size"].unique()
# Out:
# array(['3 BHK', '4 Bedroom', '2 BHK', '2 Bedroom', '1 BHK', '5 BHK',
#        '3 Bedroom', '5 Bedroom', '1 Bedroom'], dtype=object)

# %%
data[(data.size=="2 BHK") & (data.area_type == "Super built-up  Area")]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price]
# Index: []

# %%
data[(data.size=="2 BHK") & (data.area_type == "Super built-up  Area")].shape[0]
# Out:
# 0

# %%
data["price_category"] = data.price.apply(lambda x : "Affordable" if x<80 else "High Cost")

# %%
data.head()
# Out:
#               area_type   availability        location       size  society  \
# 0  Super built-up  Area  Ready To Move  Ambedkar Nagar      3 BHK      NaN
# 1            Plot  Area         18-Aug        Hulimavu  4 Bedroom  ValleCi
# 2  Super built-up  Area  Ready To Move         Kalkere      2 BHK  Sothin
# 3            Plot  Area  Ready To Move     Kodigehalli  2 Bedroom      NaN
# 4  Super built-up  Area  Ready To Move          Harlur      2 BHK  Prncyrn
#
#    total_sqft  bath  balcony  price price_category
# 0        1920   4.0      2.0  121.0      High Cost
# 1        1500   4.0      3.0  192.0      High Cost
# 2         925   2.0      1.0   55.0     Affordable
# 3         500   1.0      0.0   55.0     Affordable
# 4        1174   2.0      1.0   74.0     Affordable

# %%
data.price_category.unique()
# Out:
# array(['High Cost', 'Affordable'], dtype=object)

# %%
data["price_category1"] = "Affordable" if data.price< 80 else "High Cost"  # so better to use apply function in all cases
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-e368d19ab3f3> in <module>
# ----> 1 data["price_category1"] = "Affordable" if data.price< 80 else "High Cost"
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data.price.mean()
# Out:
# 82.0708

# %%
data[data["price"] > (data.price).mean()]
# Out:
#                area_type   availability            location       size  \
# 0   Super built-up  Area  Ready To Move      Ambedkar Nagar      3 BHK
# 1             Plot  Area         18-Aug            Hulimavu  4 Bedroom
# 9             Plot  Area  Ready To Move          Whitefield  4 Bedroom
# 16  Super built-up  Area         18-Dec              Hebbal      3 BHK
# 18        Built-up  Area  Ready To Move          Rayasandra      5 BHK
# 20  Super built-up  Area  Ready To Move         HRBR Layout      3 BHK
# 26  Super built-up  Area  Ready To Move              Jakkur      3 BHK
# 27          Carpet  Area  Ready To Move   Maruthi Sevanagar  4 Bedroom
# 31  Super built-up  Area  Ready To Move         Tumkur Road      3 BHK
# 40            Plot  Area  Ready To Move        Karuna Nagar  3 Bedroom
# 43        Built-up  Area  Ready To Move  Vishwapriya Layout  5 Bedroom
# 45  Super built-up  Area  Ready To Move         Basavangudi      2 BHK
#
# ...
